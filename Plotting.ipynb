# %% [markdown]
# https://matplotlib.org/examples/pylab_examples/set_and_get.html

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x_plot = np.arange(-5, 5, 0.01)
y_plot = 1.0/(1.0+np.exp(-x_plot))
line = plt.plot(x_plot, y_plot);
l1 = line
plt.setp(l1, linewidth=10, color="g");
